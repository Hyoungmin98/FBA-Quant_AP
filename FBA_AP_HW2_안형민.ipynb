# %% [markdown]
# # Homework 1. Textbook
#
# ## Chapter 6. Capital Allocation to Risky Assets
#
# ### 6.1 Risk and Risk Aversion
#
# Utility score: $U = E(r) - \frac{1}{2}A\sigma^2  $
# - 기대수익률이 높을수록 score가 높고 변동성이 높을수록 score가 낮다.
# - U: 효용가치, A: 위험 회피 지수
# - 투자자가 위험회피 성향이 클수록 변동성에 초점을 둠
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - 북서쪽 방향으로 갈수록 가장 선호되는 포트폴리오에 해당
# - 2사분면, 3사분면은 투자자의 위험 회피 성향에 따라 선호도가 달라짐.

# %% [markdown]
# indifference curve: 모든 포트폴리오의 동일한 효용 함수 값을 가지는 점들을 모은 곡선
# ![image.png](attachment:image.png)
#
# ### 6.2 Capital Allocation across Risky and Risk-Free Portfolios
# 위험 자산에 210,000만큼, 무위험자산에 90000만큼 투자를 한다고 가정, 이때 위험자산 A에는 113,400, 위험자산 B에는 96,600만큼 투자한다고 가정
# → $w_A = \frac{113400}{210000} = 0.54$, $w_B = \frac{96600}{210000}=0.46$, $w_f = \frac{90000}{300000}=0.3$, $w_p = \frac{210000}{300000}=0.7$
#
# ### 6.3 The Risk-Free Asset
# 채무 불이행 보증만으로는 채권을 실질적으로 무위험 자산으로 평가할 순 없음. 일반적으로는 국채를 무위험 자산으로 평가한다.
#
# ### 6.4 Portfolios of One Risky Asset and a Risk-Free Asset
# $r_C = yr_p + (1-y)r_f$
# $E(r_C) = yE(r_p) + (1-y)r_f$
# $\sigma_C = y\sigma_p$
# ($r_C$: 총 수익률, $r_p$: 위험 포트폴리오 수익률, $r_f$: 무위험 포트폴리오 수익률)
# ※ CAL(capital allocation line)
# $E(r_C) = r_f + SR*\sigma_C$
# ![image-2.png](attachment:image-2.png)
#
# ### 6.5 Risk Tolerance and Asset Allocation
# ![image-3.png](attachment:image-3.png)
# 유틸리티 함수 그래프를 통해 극댓값에서 가장 좋은 값이 나온다는 걸 알 수 있음.
# $\max_{y} U = E(r_C) - \frac{1}{2}A\sigma_C^2 = r_f + y\left[E(r_P) - r_f\right] - \frac{1}{2}Ay^2\sigma_P^2$
# $y^* = \frac{E(r_P) - r_f}{A\sigma_P^2}$
#
# - 정규성을 가정하고 표준편차를 위험 척도로 사용하였기 때문에 수익률 분포가 정규분포를 따르지 않을 경우 문제가 발생할 수 있음. 따라서 일반적으로 VaR 또는 ES도 측정하는것이 중요함.

# %% [markdown]
# # Homework2. Lecture
# ## Lesson8. Momentum Trading
# - 과거 실적을 근거삼아 주식을 매수하는 전략
# - 일반적으로 주가가 계속 증가하는 기업은 이후에도 계속 증가할 것이고 하락하는 주가는 계속 하락할 것이라고 가정
# - 주식의 상대적 성과를 통해 가중치를 조절할 수 있음
#
# ## Lesson10.  Quant Workflow
# 거래 전략 유형
# 1. Single Asset Strategies: 단일 자산 투자
# 2. Pairwise Strategies: 동일한 시장의 두 기업간의 수익률이 같다고 가정하고 만약 차이가 생겼을 때 더 높은 수익률을 기록하는 주식을 매수, 낮은 수익률을 기록하는 주식을 매도하는 전략
# 3. Cross-sectional strategies: 일시적인 시장 현상으로부터 이익을 얻으려는 목표를 가지고 수백개에서 수천개의 주식을 비교하는 전략
# 4. Alternative Data Based Strategies: 지리적 위치 또는 소비자 거래 데이터와 같은 유형의 데이터를 기반으로하는 전략
#
# Alpha: 거래 결정에 영향을 미칠 미래 수익률에 대한 확신의 척도 또는 지표
#
# ※ Risk
# Systematic Risk: 전체 시장에 내재된 위험(ex. 인플레이션, GDP ...)
# Idiosyncratic Risk: 개별 주식에 내재된 위험
#
# ## Lesson11. Outliers and Filtering
# Lookahead Bias: 미래의 알 수 없는 데이터를 사용하면서 지속적으로 결과가 더 좋게 도출되는 현상. 백테스팅 과정에서 자주 발생하며 당일의 투자 전략을 위해 당일 종가 데이터를 사용하는 등의 행동으로 발생할 수 있다.
#
# 분포가 정규분포를 따르는지를 판단하기 위해 Q-Q Plot 활용 가능
# → QQ plot: 두 번째 데이터 분위수에 대한 첫 번째 데이터 분위수의 플롯. 대각선에 점들이 모여있을 수록 정규분포에 가깝다고 할 수 있다.
# ![image.png](attachment:image.png)
#
# 이상치(Outlier): 데이터 세트에서 다른 데이터와 현저히 다른 값을 가진 관측치.
# → 주가의 경우 이동평균법, 포트폴리오의 경우 각 자산의 움직임을 평균으로 하여 이상치의 위험을 완화할 수 있음.
#
# ## Lesson12. Regression
# Regression: 하나 이상의 독립 변수(설명 변수)를 사용하여 종속 변수(반응 변수)의 값을 예측하거나 설명하는 통계적 기법
# → 데이터가 정규분포를 따르는지, 정상성을 지니는지 확인해야함.
# 1. 정규성 검정을 위해 히스토그램, 왜도&첨도, Q-Q plot 등을 활용하여 정규분포에 근사하는지 시각화 수 있음, K-S test, Shapiro-Wilk test 등으로 정규성 검정 가능.
# 2. Breusch-Pagan Test를 통해 데이터 분포가 정상성을 가지는지 판별할 수 있음
# → P-value가 0.05보다 크면 데이터가 등분산적이라고 할 수 있다.
#
#
# Signal-to-noise(신호 대 잡음비)
# ![image-2.png](attachment:image-2.png)
# 금융 데이터의 경우 신호 대 잡음비가 낮은 것으로 유명하다. 즉 다른 분야에 비해 신호(signal)는 적고 noise(잡음)가 많은 편. 이는 예측 모델이 Training set에 과대적홥 되는 결과를 불러올 수 있음.
#
# PDF(Probability Density Function): 특정 구간 내에서 확률변수가 값을 가질 확률을 나타내는 함수
# 정규분포 PDF: $f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left(-\frac{(x - \mu)^2}{2\sigma^2}\right)$
#
# Breusch-Pagan Test를 통해 데이터 분포가 정상성을 가지는지 판별할 수 있음
# → P-value가 0.05보다 크면 데이터가 등분산적이라고 할 수 있다.
#
# Box-Cox Transformation: 데이터의 분포를 정규 분포에 더 가깝게 변형하기 위해 사용되는 방법. 이를 통해 등분산성과 정규성을 만족시킬 수 있다.
# $y(\lambda) =
# \begin{cases}
# \frac{y^\lambda - 1}{\lambda} & \text{if } \lambda \neq 0 \\
# \log(y) & \text{if } \lambda = 0
# \end{cases}$
#
# - 정규분포를 따르는 데이터 분포를 통해 단순선형회귀, 다중선형회귀를 활용하여 두 변수간의 관계를 파악할 수 있음
# - 이때 만들어진 선형 모델의 정확도는 R-squared, Adjusted R-squared, F-test등을 통해 검정 가능
#
# - 종속변수가 2개 이상인 경우의 회귀모델을 다변량 회귀(Multivariate Regression)이라 부른다.

# %%
# Homework3

def get_high_lows_lookback(high, low, lookback_days):
    """
    Get the highs and lows in a lookback window.
    
    Parameters
    ----------
    high : DataFrame
        High price for each ticker and date
    low : DataFrame
        Low price for each ticker and date
    lookback_days : int
        The number of days to look back
    
    Returns
    -------
    lookback_high : DataFrame
        Lookback high price for each ticker and date
    lookback_low : DataFrame
        Lookback low price for each ticker and date
    """
    #TODO: Implement function
    lookback_high = high.shift(1).rolling(window=lookback_days).max()
    lookback_low = low.shift(1).rolling(window=lookback_days).min()
    return lookback_high, lookback_low

project_tests.test_get_high_lows_lookback(get_high_lows_lookback)

# %%
def get_long_short(close, lookback_high, lookback_low):
    """
    Generate the signals long, short, and do nothing.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookback_high : DataFrame
        Lookback high price for each ticker and date
    lookback_low : DataFrame
        Lookback low price for each ticker and date
    
    Returns
    -------
    long_short : DataFrame
        The long, short, and do nothing signals for each ticker and date
    """
    long_short = pd.DataFrame(0, index=close.index, columns=close.columns)
    
    short_signals = close < lookback_low
    long_short[short_signals] = -1

    long_signals = close > lookback_high
    long_short[long_signals] = 1
    return long_short

project_tests.test_get_long_short(get_long_short)

# %%
def clear_signals(signals, window_size):
    """
    Clear out signals in a Series of just long or short signals.
    
    Remove the number of signals down to 1 within the window size time period.
    
    Parameters
    ----------
    signals : Pandas Series
        The long, short, or do nothing signals
    window_size : int
        The number of days to have a single signal       
    
    Returns
    -------
    signals : Pandas Series
        Signals with the signals removed from the window size
    """
    # Start with buffer of window size
    # This handles the edge case of calculating past_signal in the beginning
    clean_signals = [0]*window_size
    
    for signal_i, current_signal in enumerate(signals):
        # Check if there was a signal in the past window_size of days
        has_past_signal = bool(sum(clean_signals[signal_i:signal_i+window_size]))
        # Use the current signal if there's no past signal, else 0/False
        clean_signals.append(np.int64(not has_past_signal and current_signal))
        
    # Remove buffer
    clean_signals = clean_signals[window_size:]

    # Return the signals as a Series of Ints
    return pd.Series(np.array(clean_signals).astype(np.int64), signals.index)


def filter_signals(signal, lookahead_days):
    """
    Filter out signals in a DataFrame.
    
    Parameters
    ----------
    signal : DataFrame
        The long, short, and do nothing signals for each ticker and date
    lookahead_days : int
        The number of days to look ahead
    
    Returns
    -------
    filtered_signal : DataFrame
        The filtered long, short, and do nothing signals for each ticker and date
    """
    #TODO: Implement function
    
    filtered_signal = pd.DataFrame(index=signal.index, columns=signal.columns)
    
    for ticker in signal.columns:
        filtered_signal[ticker] = clear_signals(signal[ticker], lookahead_days)
    
    return filtered_signal

project_tests.test_filter_signals(filter_signals)

# %%
def get_lookahead_prices(close, lookahead_days):
    """
    Get the lookahead prices for `lookahead_days` number of days.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookahead_days : int
        The number of days to look ahead
    
    Returns
    -------
    lookahead_prices : DataFrame
        The lookahead prices for each ticker and date
    """
    #TODO: Implement function
    lookahead_prices = close.shift(-lookahead_days)
    
    return lookahead_prices

project_tests.test_get_lookahead_prices(get_lookahead_prices)

# %%
def get_return_lookahead(close, lookahead_prices):
    """
    Calculate the log returns from the lookahead days to the signal day.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookahead_prices : DataFrame
        The lookahead prices for each ticker and date
    
    Returns
    -------
    lookahead_returns : DataFrame
        The lookahead log returns for each ticker and date
    """
    #TODO: Implement function
    lookahead_returns = np.log(lookahead_prices / close)
    
    return lookahead_returns

project_tests.test_get_return_lookahead(get_return_lookahead)

# %%
def get_signal_return(signal, lookahead_returns):
    """
    Compute the signal returns.
    
    Parameters
    ----------
    signal : DataFrame
        The long, short, and do nothing signals for each ticker and date
    lookahead_returns : DataFrame
        The lookahead log returns for each ticker and date
    
    Returns
    -------
    signal_return : DataFrame
        Signal returns for each ticker and date
    """
    #TODO: Implement function
    
    signal_return = signal * lookahead_returns
    
    return signal_return

project_tests.test_get_signal_return(get_signal_return)

# %%
from scipy.stats import kstest


def calculate_kstest(long_short_signal_returns):
    """
    Calculate the KS-Test against the signal returns with a long or short signal.
    
    Parameters
    ----------
    long_short_signal_returns : DataFrame
        The signal returns which have a signal.
        This DataFrame contains two columns, "ticker" and "signal_return"
    
    Returns
    -------
    ks_values : Pandas Series
        KS static for all the tickers
    p_values : Pandas Series
        P value for all the tickers
    """
    #TODO: Implement function
    
    ks_values = {}
    p_values = {}

    # Calculate the global mean and std across all stocks
    global_mean = long_short_signal_returns['signal_return'].mean()
    global_std = long_short_signal_returns['signal_return'].std(ddof=0)

    # Group the data by ticker
    grouped = long_short_signal_returns.groupby('ticker')

    for ticker, data in grouped:
        # Extract the signal returns for the current ticker
        signal_returns = data['signal_return']
        
        # Perform the KS test against a normal distribution with the global mean and std
        ks_stat, p_value = kstest(signal_returns, 'norm', args=(global_mean, global_std))

        # Store the results
        ks_values[ticker] = ks_stat
        p_values[ticker] = p_value

    ks_values = pd.Series(ks_values).sort_index(ascending=False)
    p_values = pd.Series(p_values).sort_index(ascending=False)
    
    return ks_values, p_values


project_tests.test_calculate_kstest(calculate_kstest)

# %%
def find_outliers(ks_values, p_values, ks_threshold, pvalue_threshold=0.05):
    """
    Find outlying symbols using KS values and P-values
    
    Parameters
    ----------
    ks_values : Pandas Series
        KS static for all the tickers
    p_values : Pandas Series
        P value for all the tickers
    ks_threshold : float
        The threshold for the KS statistic
    pvalue_threshold : float
        The threshold for the p-value
    
    Returns
    -------
    outliers : set of str
        Symbols that are outliers
    """
    #TODO: Implement function
    
    outliers = set(ks_values[(ks_values > ks_threshold) & (p_values < pvalue_threshold)].index)
    
    return outliers


project_tests.test_find_outliers(find_outliers)
